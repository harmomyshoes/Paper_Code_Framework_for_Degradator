# %%
# boxplot_notched_set2.py
# Generate a notched boxplot of rating_score by rating_stimulus
# using a Set2 color palette (matplotlib), similar to your reference image.

import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from pathlib import Path

# === Config ===
CSV_PATH = Path("df_rating_IncludePiano_Exclude_3_9_10.csv")  # change if needed
OUTPUT_PATH = Path("rating_boxplot_notched_set2.png")                    # where to save the figure


# --- Load data ---
df = pd.read_csv(CSV_PATH)
needed = {"rating_stimulus", "rating_score"}
if not needed.issubset(df.columns):
    raise ValueError(f"Missing columns: {needed - set(df.columns)}")

# Preserve category order
stim_order = pd.Categorical(df["rating_stimulus"],
                            categories=pd.unique(df["rating_stimulus"]),
                            ordered=True)
df = df.assign(rating_stimulus=stim_order)

# --- Group and labels ---
groups, labels = [], []
for stim, sub in df.sort_values("rating_stimulus").groupby("rating_stimulus"):
    labels.append(stim)
    groups.append(sub["rating_score"].to_numpy())

# --- Custom color palette (from your attached figure) ---
custom_colors = [
    "#1f77b4",  # blue
    "#ff7f0e",  # orange
    "#2ca02c",  # green
    "#d62728",  # red
    "#9467bd",  # purple
]
colors = [custom_colors[i % len(custom_colors)] for i in range(len(labels))]

# --- Plot ---
plt.figure(figsize=(14, 7), dpi=150)
bp = plt.boxplot(
    groups,
    notch=True,
    patch_artist=True,
    showfliers=True,
    widths=0.6
)

# --- Styling ---
for i, box in enumerate(bp["boxes"]):
    box.set(facecolor=colors[i], edgecolor="black", linewidth=1.4)
for whisker in bp["whiskers"]:
    whisker.set(color="black", linewidth=1.2)
for cap in bp["caps"]:
    cap.set(color="black", linewidth=1.2)
for median in bp["medians"]:
    median.set(color="black", linewidth=2.4)
for flier in bp["fliers"]:
    flier.set(marker="o", markersize=4, alpha=0.7,
              markeredgecolor="black", markerfacecolor="white")

# --- Fonts ---
plt.xticks(range(1, len(labels) + 1), labels, fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("Rating Stimulus", fontsize=16, labelpad=10)
plt.ylabel("Rating Score", fontsize=16, labelpad=10)
plt.title("Boxplot of Rating Scores by Stimulus", fontsize=18, pad=15, weight="bold")

plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_31248/327304604.py:29: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for stim, sub in df.sort_values("rating_stimulus").groupby("rating_stimulus"):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 74
#      71 plt.title("Boxplot of Rating Scores by Stimulus", fontsize=18, pad=15, weight="bold")
#      73 plt.tight_layout()
# ---> 74 plt.savefig(out_path, bbox_inches="tight")
#      75 print(f"Saved figure to: {out_path.resolve()}")
#      76 plt.show()
#
# NameError: name 'out_path' is not defined

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("df_rating_IncludePiano_Exclude_3_9_10.csv")

# Group by 'rating_stimulus' and calculate mean and std
stats = (
    df.groupby("rating_stimulus")["rating_score"]
      .agg(["mean", "std", "count"])  # include count if you also want sample size
      .reset_index()
      .sort_values("mean", ascending=False)  # optional: sort by mean
)

# Print nicely
print(stats.to_string(index=False))
# Out:
# rating_stimulus      mean       std  count
#             wav 75.982143 21.312031    336
#             96k 74.458333 21.094770    336
#      wav_muk_EQ 59.482143 23.441250    336
#      96k_muk_EQ 57.148810 23.716268    336
#       wav_ak_EQ 52.071429 24.516719    336
#       96k_ak_EQ 47.821429 24.744141    336
#             32k 39.916667 30.841514    336
